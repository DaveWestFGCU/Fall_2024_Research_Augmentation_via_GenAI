# %%
relative_path = "../original_datasets/StackOverflow/"
labels_path = "exports_from_xlsx/"
import os
filenames = []
for entry in os.scandir(relative_path+labels_path):
    if entry.is_file():
        filenames.append(entry.name)
    
label_files = {}    
for filename in filenames:
    label = filename.split("_")[2][:-4]
    label_files[label] = relative_path + labels_path + filename

for label, filename in label_files.items():
    print(f"{label}: {filename}")
# Out:
# anger: ../original_datasets/StackOverflow/records_by_label/stack_overflow_anger.csv
# fear: ../original_datasets/StackOverflow/records_by_label/stack_overflow_fear.csv
# joy: ../original_datasets/StackOverflow/records_by_label/stack_overflow_joy.csv
# love: ../original_datasets/StackOverflow/records_by_label/stack_overflow_love.csv
# sadness: ../original_datasets/StackOverflow/records_by_label/stack_overflow_sadness.csv
# surprise: ../original_datasets/StackOverflow/records_by_label/stack_overflow_surprise.csv

# %% [markdown]
# # Load datasets and remove duplicates

# %%
import pandas as pd

label_dataframes = {}
stack_overflow_df = pd.DataFrame()
total = 0

for label, filename in label_files.items():
    # Get the data into a dataframe
    label_dataframes[label] = pd.read_csv(filename, encoding='ISO-8859-1')
    
    # Get rid of unlabeled entries
    label_dataframes[label].dropna(subset=['Gold Label'], inplace=True)
    
    # Get label count
    print(f"{label}: {len(label_dataframes[label])}")
    total += len(label_dataframes[label])
    
    # Remove second+ copies of an entry in a label
    label_dataframes[label].drop_duplicates(subset=['Text'], keep='first', inplace=True)
    
    # Add to the combined labels dataframe
    stack_overflow_df = pd.concat([stack_overflow_df, label_dataframes[label]])
    
print(f"TOTAL: {total}")
# Per paper, label counts should be:
# Love :   1220
# Joy :     491
# Surprise : 45
# Anger :   882
# Sadness : 230
# Fear :    106
# TOTAL :  2974
# Out:
# anger: 882
# fear: 106
# joy: 491
# love: 1220
# sadness: 230
# surprise: 45
# TOTAL: 2974

# %%
# Clean up dataframe

stack_overflow_df.columns=['Group', 'Set', 'Id', 'Text', 'Rater 1', 'Rater 2', 'Rater 3', 'Gold Label', 'Empty1', 'Empty2']
stack_overflow_df.drop(['Empty1', 'Empty2'], axis=1, inplace=True)
stack_overflow_df.sort_values(['Group', 'Set', 'Id'], ascending=True, inplace=True)

# %%
# Remove all copies of any duplicates, because at this point they have different labels 
stack_overflow_df.drop_duplicates(subset=['Text'], keep=False, inplace=True)

stack_overflow_df
# Out:
#      Group    Set     Id                                               Text  \
# 1100     A  Pilot    1.0  Vineet, what you are trying to do is a terribl...
# 1101     A  Pilot    2.0                           'Course I do, corrected.
# 1103     A  Pilot    4.0  @DrabJay: excellent suggestion! Code changed. :-)
# 1106     A  Pilot    7.0  It is specific, I'm not asking for a discussio...
# 1107     A  Pilot    8.0  @talnicolas I'm using it a few dozen times in ...
# ...    ...    ...    ...                                                ...
# 4792     D  Third  493.0  Nick Rigby wrote an excellent article for A Li...
# 4794     D  Third  495.0     +1 from me, I loved the leap from MFC to Qt ;)
# 4795     D  Third  496.0  Yes - that feature is extremely useful for wri...
# 4796     D  Third  497.0  Works great! And you can add "desc" after the ...
# 4798     D  Third  499.0  Fortunately I'm doing *very* little with Offic...
#
#      Rater 1 Rater 2 Rater 3 Gold Label
# 1100       X       X       x      ANGER
# 1101       X       X       x        JOY
# 1103       X       X       x        JOY
# 1106       X     NaN       x      ANGER
# 1107       X       x     NaN      ANGER
# ...      ...     ...     ...        ...
# 4792       x       X       x       LOVE
# 4794       x       X       x       LOVE
# 4795       x       X     NaN        JOY
# 4796       x     NaN       x       LOVE
# 4798       x       X       x       LOVE
#
# [2629 rows x 8 columns]

# %% [markdown]
# # Exporting

# %%
stack_overflow_df.to_csv(f"{relative_path}stack_overflow.csv", index=False)

# %% [markdown]
# # Other cleaning?

# %%
from nltk.tokenize import TweetTokenizer
tknzr = TweetTokenizer(strip_handles=True)

# %%
stack_overflow_df.insert(4, 'Tokenized',
                         stack_overflow_df.apply(lambda row: tknzr.tokenize(row.Text), axis=1)
                         )


stack_overflow_df
# Out:
#      Group    Set     Id                                               Text  \
# 1100     A  Pilot    1.0  Vineet, what you are trying to do is a terribl...
# 1101     A  Pilot    2.0                           'Course I do, corrected.
# 1103     A  Pilot    4.0  @DrabJay: excellent suggestion! Code changed. :-)
# 1106     A  Pilot    7.0  It is specific, I'm not asking for a discussio...
# 1107     A  Pilot    8.0  @talnicolas I'm using it a few dozen times in ...
# ...    ...    ...    ...                                                ...
# 4792     D  Third  493.0  Nick Rigby wrote an excellent article for A Li...
# 4794     D  Third  495.0     +1 from me, I loved the leap from MFC to Qt ;)
# 4795     D  Third  496.0  Yes - that feature is extremely useful for wri...
# 4796     D  Third  497.0  Works great! And you can add "desc" after the ...
# 4798     D  Third  499.0  Fortunately I'm doing *very* little with Offic...
#
#                                               Tokenized Rater 1 Rater 2  \
# 1100  [Vineet, ,, what, you, are, trying, to, do, is...       X       X
# 1101                [', Course, I, do, ,, corrected, .]       X       X
# 1103  [:, excellent, suggestion, !, Code, changed, ....       X       X
# 1106  [It, is, specific, ,, I'm, not, asking, for, a...       X     NaN
# 1107  [I'm, using, it, a, few, dozen, times, in, my,...       X       x
# ...                                                 ...     ...     ...
# 4792  [Nick, Rigby, wrote, an, excellent, article, f...       x       X
# 4794  [+, 1, from, me, ,, I, loved, the, leap, from,...       x       X
# 4795  [Yes, -, that, feature, is, extremely, useful,...       x       X
# 4796  [Works, great, !, And, you, can, add, ", desc,...       x     NaN
# 4798  [Fortunately, I'm, doing, *, very, *, little, ...       x       X
#
#      Rater 3 Gold Label
# 1100       x      ANGER
# 1101       x        JOY
# 1103       x        JOY
# 1106       x      ANGER
# 1107     NaN      ANGER
# ...      ...        ...
# 4792       x       LOVE
# 4794       x       LOVE
# 4795     NaN        JOY
# 4796       x       LOVE
# 4798       x       LOVE
#
# [2629 rows x 9 columns]

# %%
stack_overflow_df.insert(5, 'Tokens',
                         stack_overflow_df.apply(lambda row: len(row.Tokenized), axis=1)
                         )

stack_overflow_df
# Out:
#      Group    Set     Id                                               Text  \
# 1100     A  Pilot    1.0  Vineet, what you are trying to do is a terribl...
# 1101     A  Pilot    2.0                           'Course I do, corrected.
# 1103     A  Pilot    4.0  @DrabJay: excellent suggestion! Code changed. :-)
# 1106     A  Pilot    7.0  It is specific, I'm not asking for a discussio...
# 1107     A  Pilot    8.0  @talnicolas I'm using it a few dozen times in ...
# ...    ...    ...    ...                                                ...
# 4792     D  Third  493.0  Nick Rigby wrote an excellent article for A Li...
# 4794     D  Third  495.0     +1 from me, I loved the leap from MFC to Qt ;)
# 4795     D  Third  496.0  Yes - that feature is extremely useful for wri...
# 4796     D  Third  497.0  Works great! And you can add "desc" after the ...
# 4798     D  Third  499.0  Fortunately I'm doing *very* little with Offic...
#
#                                               Tokenized  Tokens Rater 1  \
# 1100  [Vineet, ,, what, you, are, trying, to, do, is...      61       X
# 1101                [', Course, I, do, ,, corrected, .]       7       X
# 1103  [:, excellent, suggestion, !, Code, changed, ....       8       X
# 1106  [It, is, specific, ,, I'm, not, asking, for, a...      23       X
# 1107  [I'm, using, it, a, few, dozen, times, in, my,...      47       X
# ...                                                 ...     ...     ...
# 4792  [Nick, Rigby, wrote, an, excellent, article, f...      21       x
# 4794  [+, 1, from, me, ,, I, loved, the, leap, from,...      14       x
# 4795  [Yes, -, that, feature, is, extremely, useful,...      12       x
# 4796  [Works, great, !, And, you, can, add, ", desc,...      43       x
# 4798  [Fortunately, I'm, doing, *, very, *, little, ...      30       x
#
#      Rater 2 Rater 3 Gold Label
# 1100       X       x      ANGER
# 1101       X       x        JOY
# 1103       X       x        JOY
# 1106     NaN       x      ANGER
# 1107       x     NaN      ANGER
# ...      ...     ...        ...
# 4792       X       x       LOVE
# 4794       X       x       LOVE
# 4795       X     NaN        JOY
# 4796     NaN       x       LOVE
# 4798       X       x       LOVE
#
# [2629 rows x 10 columns]

# %%
stack_overflow_df[stack_overflow_df['Tokens'] < 3]
# Out:
#      Group     Set     Id                Text               Tokenized  Tokens  \
# 258      A  Second  259.0             #ERROR!             [#ERROR, !]       2
# 784      A   Third  185.0    Excellent answer     [Excellent, answer]       2
# 838      A   Third  239.0     totally awesome      [totally, awesome]       2
# 2389     B   Third  490.0    Congratulations!    [Congratulations, !]       2
# 4195     D  Second  496.0    Beaaaaaaautiful!    [Beaaaaaaautiful, !]       2
# 4467     D   Third  168.0  goooooooooooooood!  [goooooooooooooood, !]       2
#
#      Rater 1 Rater 2 Rater 3 Gold Label
# 258        X       x       X       LOVE
# 784        X       x       X       LOVE
# 838        X       x       X       LOVE
# 2389       X       x       x       LOVE
# 4195       x     NaN       x       LOVE
# 4467       x       X       x        JOY

# %%
stack_overflow_df[stack_overflow_df['Text'].str.contains(":") & ~stack_overflow_df['Text'].str.contains(": ")]
# Out:
#      Group    Set     Id                                               Text  \
# 1138     A  Pilot   39.0  Not for me, but I can suggest some possibiliti...
# 1145     A  Pilot   46.0  Here's a secret. In the chrome dev tools, do a...
# 1168     A  Pilot   69.0  I'm starting my first Drupal project, pretty e...
# 1170     A  Pilot   71.0  It's not a homework, and since there is nowher...
# 1180     A  Pilot   81.0                                Excellent point! :)
# ...    ...    ...    ...                                                ...
# 4682     D  Third  383.0  +1 for the docbkx Maven plugin, it provides ev...
# 4689     D  Third  390.0  Great question! There have already been a few ...
# 4726     D  Third  427.0          pr0n for sure :))))))) (kidding Jonathan)
# 4786     D  Third  487.0  @StoneFree welcome to the future brave time tr...
# 4790     D  Third  491.0                                Excellent resource:
#
#                                               Tokenized  Tokens Rater 1  \
# 1138  [Not, for, me, ,, but, I, can, suggest, some, ...     189     NaN
# 1145  [Here's, a, secret, ., In, the, chrome, dev, t...     128       X
# 1168  [I'm, starting, my, first, Drupal, project, ,,...     101       X
# 1170  [It's, not, a, homework, ,, and, since, there,...      27       X
# 1180                          [Excellent, point, !, :)]       4       X
# ...                                                 ...     ...     ...
# 4682  [+, 1, for, the, docbkx, Maven, plugin, ,, it,...      37       x
# 4689  [Great, question, !, There, have, already, bee...      15       x
# 4726  [pr0n, for, sure, :), ), ), (, kidding, Jonath...      10       x
# 4786  [welcome, to, the, future, brave, time, travel...       9     NaN
# 4790                           [Excellent, resource, :]       3       x
#
#      Rater 2 Rater 3 Gold Label
# 1138       X       x      ANGER
# 1145       X       x        JOY
# 1168       X       x        JOY
# 1170       X       x        JOY
# 1180       X       x        JOY
# ...      ...     ...        ...
# 4682       X       x       LOVE
# 4689     NaN       x       LOVE
# 4726       X       x        JOY
# 4786       X       x        JOY
# 4790     NaN       x       LOVE
#
# [345 rows x 10 columns]

# %%
stack_overflow_df[stack_overflow_df['Text'].str.contains(":")]
# Out:
#      Group    Set     Id                                               Text  \
# 1103     A  Pilot    4.0  @DrabJay: excellent suggestion! Code changed. :-)
# 1116     A  Pilot   17.0  When I refactor the following line: using Resh...
# 1120     A  Pilot   21.0  To push it to Heroku, you'll have to add it to...
# 1130     A  Pilot   31.0  @njahnke: to me, it does not matter what they ...
# 1134     A  Pilot   35.0  I absolutely hate cluttered seed files. Admitt...
# ...    ...    ...    ...                                                ...
# 4754     D  Third  455.0  I have a small WPF application that hosts a Ri...
# 4777     D  Third  478.0  I have the following code for searching multip...
# 4780     D  Third  481.0  Dave, very nice!! I didn't know that was in th...
# 4786     D  Third  487.0  @StoneFree welcome to the future brave time tr...
# 4790     D  Third  491.0                                Excellent resource:
#
#                                               Tokenized  Tokens Rater 1  \
# 1103  [:, excellent, suggestion, !, Code, changed, ....       8       X
# 1116  [When, I, refactor, the, following, line, :, u...      51       X
# 1120  [To, push, it, to, Heroku, ,, you'll, have, to...      71     NaN
# 1130  [:, to, me, ,, it, does, not, matter, what, th...      43       X
# 1134  [I, absolutely, hate, cluttered, seed, files, ...     109       X
# ...                                                 ...     ...     ...
# 4754  [I, have, a, small, WPF, application, that, ho...      84       x
# 4777  [I, have, the, following, code, for, searching...      93     NaN
# 4780  [Dave, ,, very, nice, !, !, I, didn't, know, t...      57       x
# 4786  [welcome, to, the, future, brave, time, travel...       9     NaN
# 4790                           [Excellent, resource, :]       3       x
#
#      Rater 2 Rater 3 Gold Label
# 1103       X       x        JOY
# 1116       X       x      ANGER
# 1120       X       x      ANGER
# 1130       X       x      ANGER
# 1134       X       x      ANGER
# ...      ...     ...        ...
# 4754       X       x       LOVE
# 4777       X       x        JOY
# 4780     NaN       x       LOVE
# 4786       X       x        JOY
# 4790     NaN       x       LOVE
#
# [853 rows x 10 columns]
